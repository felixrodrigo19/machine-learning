# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('../input/airbnbopendata/Airbnb_Open_Data.csv')
df.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# ...

# %%
columns = ['id',
           'host id',
           'host_identity_verified',
           'neighbourhood group',
           'neighbourhood',
           'country', 
           'service fee',
           'minimum nights',
           'number of reviews',
           'reviews per month',
           'review rate number',
           'calculated host listings count',
           'availability 365',
           'house_rules']

# %%
df = df[columns]

# %%
df.isna().sum()
# Out:
# id                                    0
# host id                               0
# host_identity_verified              289
# neighbourhood group                  29
# neighbourhood                        16
# country                             532
# service fee                         273
# minimum nights                      409
# number of reviews                   183
# reviews per month                 15879
# review rate number                  326
# calculated host listings count      319
# availability 365                    448
# house_rules                       52131
# dtype: int64

# %%
df=df.dropna()

# %%
df.sum()

# %%
df['review rate number'].unique()

# %%
plt.plot(df['review rate number'].value_counts())
plt.ylabel('review rate number')
plt.show()

# %%
df['review rate number'].value_counts().plot().bar()

# %%
fig, ax = plt.subplots()
ax.scatter(df['review rate number'], df['service fee'].to_string)

ax.set_xlabel('review rate number', fontsize=15)
ax.set_ylabel('review rate number', fontsize=15)

ax.grid(True)
fig.tight_layout()

plt.show()
